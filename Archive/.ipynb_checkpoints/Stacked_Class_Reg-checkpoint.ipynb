# %%
import pandas as pd
from pandas.plotting import scatter_matrix

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.cross_validation import ShuffleSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, confusion_matrix, r2_score, classification_report

import math

from collections import defaultdict
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
file = "/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/master_df_20191106.xlsx"
data = pd.read_excel(file)
df_master = pd.DataFrame(data).set_index('FIPS')

# %%
df_master.columns
# Out:
# Index(['PropSFHA', 'PropDG', 'AveLS', 'MaxDepth', 'HurTrack', 'PeakGust',
#        'MaxSusta', 'StrVI', 'SeVI', 'Str+SeVI', 'SoVI', 'AveDepth', 'O_Ind',
#        'R_Ind', 'PropSComm', 'R_I_No0', 'R_I_NoO', 'R_I_No0_NoO', 'cat_3q',
#        'cat_4q', 'Count', 'R_DES', 'R_AFF', 'Ex_Q4_c'],
#       dtype='object')

# %%
df_master.groupby('cat_4q').size()
# Out:
# cat_4q
# 0    217
# 1    225
# 2    223
# 3    217
# dtype: int64

# %%
def choose_data(df_master, feature_list, target_list):
    choices = feature_list + target_list
    df = df_master[choices].copy()
    df.dropna(inplace = True)
    return df

# %%
# EXAMPLE:
feature_list = ['PropSFHA', 'PropDG', 'AveLS', 'HurTrack',
                'PeakGust', 'StrVI', 'SeVI', 'AveDepth', 'PropSComm']
target_list = ['cat_4q']

df = choose_data(df_master, feature_list, target_list)

# %%
def partition_data(df, target_str):
    y = df[target_str]
    df_x = df.drop(target_str, axis = 1)
    return y, df_x

# %%
# EXAMPLE:
target_str = 'cat_4q'
y, df_x = partition_data(df, target_str)

# %%
def split_the_data_stratify(df_x, y):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y, 
                                                        test_size=0.2, 
                                                        random_state=42,
                                                        stratify = df_master['cat_4q'])
    return x_train, x_test, y_train, y_test

# %%
def split_the_data(df_x, y):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y, 
                                                        test_size=0.2, 
                                                        random_state=42)
                                                        
    return x_train, x_test, y_train, y_test

# %%
# Careful of Random State
# Change y_binned to y if categorical
# EXAMPLE:
x_train, x_test, y_train, y_test = split_the_data_stratify(df_x, y)

# %%
y_train.hist()

# %% [markdown]
# # Start with RF Classifier then syphon into multiple regressions

# %%
def randomized_cv(x_train, y_train, model):
    # Number of trees in random forest
    n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 10)]
    # Number of features to consider at every split
    max_features = ['auto', 'sqrt']
    # Maximum number of levels in tree
    max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
    max_depth.append(None)
    # Minimum number of samples required to split a node
    min_samples_split = [2, 5, 10]
    # Minimum number of samples required at each leaf node
    min_samples_leaf = [1, 2, 4]

    # Create the random grid
    random_grid = {'n_estimators': n_estimators,
                   'max_features': max_features,
                   'max_depth': max_depth,
                   'min_samples_split': min_samples_split,
                   'min_samples_leaf': min_samples_leaf}
    
    # Use the random grid to search for best hyperparameters
    # First create the base model to tune
    rf = model
    # Random search of parameters, using cv = cross validation, 
    # search across 100 different combinations, and use all available cores
    rf_randomized_cv = RandomizedSearchCV(estimator = rf, 
                                          param_distributions = random_grid, 
                                          n_iter = 100, 
                                          cv = 5, 
                                          verbose=2, 
                                          random_state=42, 
                                          n_jobs = -1)
    
    # Fit the random search model
    rf_randomized_cv.fit(x_train, y_train)
    
    print(rf_randomized_cv.best_params_)
    return rf_randomized_cv.best_estimator_

# %%
#EXAMPLE
#Random state
#CHOOSE IF REGRESSOR OR CLASSIFICATION
random_tuned_model = randomized_cv(x_train, y_train, RandomForestClassifier())
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.7s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.8s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.8s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   5.6s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   5.6s
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   5.6s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   5.6s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   5.7s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   2.1s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   2.0s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   2.0s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   2.0s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   1.9s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   2.0s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   1.9s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   1.9s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   1.9s
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   1.9s
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.8s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.8s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.2s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.8s
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.4s
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   4.5s
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   4.5s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.4s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.4s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   4.6s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   4.6s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   4.7s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.6s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.6s
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.6s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   3.7s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.7s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.6s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   3.7s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   3.7s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   3.8s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   3.8s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.7s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   4.2s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   4.2s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   4.2s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   4.2s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   4.2s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.9s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.8s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.7s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.7s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.7s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   2.7s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   2.6s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   2.6s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   2.6s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   2.6s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   4.5s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   4.5s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   4.5s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   4.4s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   4.5s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   0.9s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   0.9s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   0.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   0.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   0.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   5.6s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   5.7s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   5.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   5.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   5.7s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.4s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.8s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.8s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.8s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   3.6s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   3.5s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   3.5s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   3.6s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   3.6s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.5s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.5s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.5s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.6s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.7s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   1.0s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   0.9s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.1s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.2s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   3.4s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   3.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   3.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   56.3s
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   3.4s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   3.4s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.6s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.5s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.5s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.2s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.5s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.5s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.3s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.3s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.1s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.2s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.9s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.9s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.9s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.9s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   2.9s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.2s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.7s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.7s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.7s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.8s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.6s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.5s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.5s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.7s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   4.8s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   4.7s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   4.7s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   4.7s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.6s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.4s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   4.7s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.6s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.4s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.6s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.6s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.5s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   0.9s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   0.9s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   0.9s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   0.9s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   0.9s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.3s
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   5.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   5.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   5.8s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   3.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   3.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   3.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   6.1s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   6.0s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80, total=   2.4s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80, total=   2.5s
# [CV]  n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80, total=   2.4s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80, total=   2.4s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# ...
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   2.7s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   2.7s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   2.7s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   4.8s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   4.9s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   4.9s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   4.9s
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   4.9s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   5.3s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   5.4s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.4s
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.4s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   3.5s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   5.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   5.2s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   5.2s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   5.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   5.2s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   6.0s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   6.0s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   6.0s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   6.1s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.2s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   6.0s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   3.5s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   0.9s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   0.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   0.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   0.9s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   3.5s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   3.5s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   3.6s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   3.5s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.1s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.1s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   4.9s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   4.9s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   5.0s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.5s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.5s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.5s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.1s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.0s
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   4.4s
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   4.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  3.3min finished
# {'n_estimators': 2000, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 60}

# %%
random_tuned_model.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=60, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=2000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)>

# %%
def grid_cv(x_train, y_train, model):
    param_grid = {
        'max_depth': [20, 30, 50, 60],
        'max_features': [2, 3, 4],
        'min_samples_leaf': [1, 3, 5],
        'min_samples_split': [5, 8, 10],
        'n_estimators': [1000, 2000]
    }
    # Create a based model
    rf = model
    # Instantiate the grid search model
    grid_search = GridSearchCV(estimator = rf, 
                               param_grid = param_grid, 
                               cv = 5, n_jobs = -1, 
                               verbose = 2)
    grid_search.fit(x_train, y_train)
    
    print(grid_search.best_params_)
    return grid_search.best_estimator_

# %%
#Example
#CHOOSE IF REGRESSOR OR CLASSIFICATION
tuned_model = grid_cv(x_train, y_train, RandomForestClassifier())
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   2.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   2.4s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   2.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   2.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   5.0s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   5.1s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   5.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   2.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   2.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   5.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   5.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   2.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   4.9s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   4.9s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   5.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   2.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   5.0s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   2.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   14.0s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   2.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.2s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.2s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.3s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.4s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   7.2s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   7.2s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   7.2s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   7.3s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   7.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.9s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   5.8s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.6s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.5s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   7.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   7.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   7.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   7.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   7.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   5.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.5min
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   5.9s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.9s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.4s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.4s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.5s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.5s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.5s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.4s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.4s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.5s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.7s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.8s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.9s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.7s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   7.0s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.7s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.6s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.8s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.3s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.2s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=20, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.4s
# ...
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.4s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.4s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, total=   6.4s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=8, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   3.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, total=   6.7s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   3.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, total=   3.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   3.1s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   6.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   6.7s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   3.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   6.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   6.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=2000, total=   7.0s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   3.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=1000, total=   3.7s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   3.3s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   3.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   3.2s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   6.5s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   6.6s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   6.5s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=8, n_estimators=2000, total=   6.7s
# [CV] max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   3.0s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=1000, total=   2.8s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   5.0s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   4.7s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   4.6s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   4.7s
# [CV]  max_depth=60, max_features=4, min_samples_leaf=5, min_samples_split=10, n_estimators=2000, total=   4.7s
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed: 10.8min finished
# {'max_depth': 50, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 1000}

# %%
tuned_model.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=50, max_features=2, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3, min_samples_split=8,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)>

# %%
def run_tuned_model(x_train,y_train):
    tuned_model.fit(x_train, y_train)
    return tuned_model

# %%
hypertune_model = run_tuned_model(x_train, y_train)

# %%
def prediction(model, x_train, x_test):
    pred_train = model.predict(x_train)
    pred_test = model.predict(x_test)   
    return pred_train, pred_test

# %%
# EXAMPLE
#CHOOSE MODEL
pred_train, pred_test = prediction(hypertune_model, x_train, x_test)

# %%
def evaluate_classification(model, x_train, x_test, y_train, y_test):
    pred = model.predict(x_test)
    accuracy_train = model.score(x_train, y_train)
    print('The mean training accuracy is {}'.format(accuracy_train))
    accuracy_test = model.score(x_test, y_test)
    print('The mean test accuracy is {}'.format(accuracy_test))
    df_confusion = pd.DataFrame(confusion_matrix(y_test, pred))
    print(df_confusion)
    print(classification_report(y_test, pred))
    return df_confusion

# %%
# EXAMPLE
# CHOOSE MODEL IF WANT TUNED OR JUST CLASSIFICATION WITH DEFAULT
df_confusion = evaluate_classification(hypertune_model, x_train, x_test, y_train, y_test)
# Out:
# The mean training accuracy is 0.9205673758865248
# The mean test accuracy is 0.4350282485875706
#     0   1   2   3
# 0  22   5   5  12
# 1   8  18   9  10
# 2  12  14  10   9
# 3   2   3  11  27
#              precision    recall  f1-score   support
#
#           0       0.50      0.50      0.50        44
#           1       0.45      0.40      0.42        45
#           2       0.29      0.22      0.25        45
#           3       0.47      0.63      0.53        43
#
# avg / total       0.42      0.44      0.43       177

# %%
def plot_confusion(df_confusion):
    sns.set(font_scale=1.4)#for label size
    sns.heatmap(df_confusion, cmap='PuBu', annot=True, annot_kws={"size": 16})# font size
    plt.ylabel('Predicted')
    plt.xlabel('True Value')
    plt.show()

# %%
# EXAMPLE
plot_confusion(df_confusion)

# %%
df_y_test_pred = pd.DataFrame(y_test)
df_y_test_pred['cat_4q_pred'] = pred_test
df_y_train = pd.DataFrame(y_train)

Target = pd.DataFrame(df_master['R_Ind'])

Test_reg = x_test.merge(df_y_test_pred, right_index=True, left_index=True, how='left').merge(Target, right_index=True, left_index=True, how='left')

Train_reg = x_train.merge(df_y_train, right_index=True, left_index=True, how='left').merge(Target, right_index=True, left_index=True, how='left')

# %%
Train_reg
# Out:
#              PropSFHA  PropDG  AveLS  HurTrack  PeakGust  StrVI   SeVI  \
# FIPS
# 72025201600      0.00    0.01   1.00      0.11     58.12  -2.66  -0.58
# 72021031101      0.00    0.00   1.00      0.16     58.56  -0.18   8.28
# 72041240602      0.01    0.00   1.29      0.02     54.99   5.03   6.39
# 72043954000      0.00    0.00   1.21      0.16     50.52  -0.06   1.26
# 72031051102      0.00    0.00   1.00      0.27     60.80   0.64   1.28
# 72135510101      0.00    0.00   1.00      0.16     59.01  -3.51   5.51
# 72127005103      0.00    0.00   0.33      0.27     61.24   1.02  -5.34
# 72113071900      0.79    0.05   1.00      0.36     42.02   1.11  -2.74
# 72063210504      0.00    0.00   1.38      0.16     59.90   0.54  11.44
# 72123952900      0.08    0.00   1.00      0.20     49.17   1.56   3.42
# 72023830504      0.50    0.00   1.00      0.55     34.87   8.37  -2.92
# 72033020425      0.00    0.00   1.00      0.23     60.80   0.70  -4.31
# 72097081000      0.01    0.00   1.33      0.42     36.21  -2.91  -3.29
# 72025202800      0.00    0.00   1.90      0.05     56.33   2.85   1.53
# 72031050600      0.75    0.00   1.00      0.29     60.35  -4.16   8.09
# 72039955600      0.02    0.01   0.93      0.03     50.96   3.69   0.06
# 72021031403      0.05    0.00   1.00      0.16     58.56  -0.78   1.01
# 72139060403      0.06    0.01   1.25      0.24     61.69  -3.37   6.46
# 72127005101      0.00    0.00   0.00      0.28     60.80  -3.49   2.42
# 72097080400      0.99    0.00   1.00      0.42     36.66  -2.59  -5.24
# 72127002300      0.00    0.00   1.00      0.28     61.24  -6.43 -15.32
# 72153750101      0.00    0.00   1.83      0.35     42.02   1.08  -2.76
# 72127002600      0.09    0.00   1.00      0.28     61.69  -7.73 -12.57
# 72129220700      0.00    0.00   1.60      0.04     57.22  -0.18  -5.47
# 72085190102      0.00    0.00   1.00      0.17     61.69  -1.40   6.73
# 72037160201      0.15    0.00   1.25      0.36     54.99  -3.04  -0.86
# 72001956700      0.10    0.00   2.00      0.26     43.81   1.30  -6.66
# 72031050242      0.12    0.00   1.00      0.29     59.90  -2.42   3.42
# 72029100200      0.87    0.02   1.00      0.31     58.12  -5.18  -1.38
# 72071410401      0.05    0.00   0.44      0.12     42.02   2.27   2.27
# ...               ...     ...    ...       ...       ...    ...    ...
# 72003430602      0.49    0.00   0.88      0.31     37.10   6.27   4.53
# 72113072101      0.66    0.00   1.00      0.38     41.57  -1.22  -5.50
# 72065310200      0.34    0.40   1.00      0.03     45.60   7.31   1.70
# 72109290200      0.21    0.11   1.38      0.05     54.99   3.14  -2.26
# 72057270300      0.07    0.00   1.18      0.11     53.64  -0.33  -1.49
# 72031050302      0.00    0.00   1.00      0.29     60.35  -4.26   4.03
# 72051540500      0.07    0.00   1.00      0.17     57.22   3.94   7.65
# 72013302202      0.00    0.00   0.80      0.02     49.62   5.14   1.52
# 72055961000      0.38    0.46   1.00      0.51     37.55   2.75  -2.41
# 72047530300      0.07    0.00   1.50      0.07     56.77   0.54   0.74
# 72139060212      0.00    0.00   1.00      0.24     61.69   3.07   4.43
# 72091570500      0.00    0.00   0.67      0.09     53.20  -2.68   1.89
# 72065310300      0.02    0.02   1.00      0.04     46.49   7.11  -2.53
# 72119130102      0.64    0.12   1.00      0.39     54.09  -4.03   2.29
# 72023830300      0.15    0.01   1.00      0.53     34.87   5.32   2.19
# 72031050111      0.33    0.00   1.00      0.32     60.80  -7.94   5.10
# 72127008603      0.25    0.00   1.00      0.24     61.24  -4.81   0.62
# 72043954200      0.02    0.00   1.00      0.19     49.62  -0.21   5.12
# 72063210300      0.36    0.17   1.00      0.17     60.35  -2.21  -6.45
# 72127003501      0.20    0.00   0.75      0.28     60.80   4.26  -9.65
# 72101955202      0.00    0.00   1.08      0.04     54.54   6.55   0.74
# 72103170200      0.06    0.05   1.04      0.26     59.90  -0.21  -0.67
# 72091570300      0.00    0.00   0.33      0.07     52.75  -3.38  -3.25
# 72029100504      0.05    0.01   1.11      0.30     59.01  -3.04  -0.98
# 72127008602      0.20    0.01   1.00      0.24     61.24  -2.81   5.19
# 72061040103      0.38    0.00   0.00      0.24     62.14   1.13  -3.71
# 72153750602      0.10    0.10   1.00      0.48     38.45  -0.38   3.70
# 72137120600      0.01    0.95   1.00      0.23     60.80  -2.81   1.70
# 72121960700      0.06    0.00   1.00      0.47     38.00   2.59   3.61
# 72011810600      0.50    0.57   1.36      0.35     36.66   2.70   0.71
#
#              AveDepth  PropSComm  cat_4q     R_Ind
# FIPS
# 72025201600      0.35   0.374465       2  0.035413
# 72021031101      0.00   0.001675       1  0.013477
# 72041240602      0.00   0.013273       1  0.011466
# 72043954000      0.00   0.002270       3  0.124171
# 72031051102      0.00   0.000421       3  0.071468
# 72135510101      0.00   0.000000       0  0.003766
# 72127005103      0.00   0.388858       2  0.033784
# 72113071900      1.28   0.039803       1  0.011928
# 72063210504      0.00   0.000000       2  0.043819
# 72123952900      0.00   0.037913       0  0.000000
# 72023830504      0.00   0.422843       3  0.047844
# 72033020425      0.00   0.025531       1  0.009174
# 72097081000      0.00   0.291257       2  0.028681
# 72025202800      0.00   0.009585       2  0.027576
# 72031050600      0.00   0.000109       1  0.019634
# 72039955600      5.36   0.000148       3  0.120271
# 72021031403      0.00   0.000000       1  0.021134
# 72139060403      1.97   0.000000       1  0.006873
# 72127005101      0.00   0.399590       0  0.000000
# 72097080400      0.00   0.389302       0  0.002427
# 72127002300      0.00   0.000000       0  0.002053
# 72153750101      4.58   0.252132       3  0.069706
# 72127002600      0.00   0.560679       2  0.033223
# 72129220700      1.03   0.000000       3  0.069611
# 72085190102      0.00   0.004348       1  0.018708
# 72037160201      0.00   0.000000       2  0.031186
# 72001956700      0.00   0.007543       0  0.000000
# 72031050242      0.00   0.000000       1  0.014868
# 72029100200      2.10   0.000000       1  0.020408
# 72071410401      0.00   0.025176       3  0.073352
# ...               ...        ...     ...       ...
# 72003430602      0.00   0.017559       2  0.029898
# 72113072101      0.00   0.028275       1  0.016515
# 72065310200      3.60   0.014284       1  0.010493
# 72109290200      2.77   0.000185       2  0.042184
# 72057270300      0.00   0.000000       3  0.050538
# 72031050302      0.00   0.075942       2  0.039088
# 72051540500      0.00   0.005744       3  0.053909
# 72013302202      0.00   0.000009       3  0.056083
# 72055961000      4.53   0.022780       2  0.028796
# 72047530300      0.00   0.047209       3  0.074530
# 72139060212      0.00   0.000000       0  0.000961
# 72091570500      0.00   0.000000       2  0.027827
# 72065310300      2.06   0.002544       3  0.074933
# 72119130102      2.11   0.000000       1  0.016863
# 72023830300      0.44   0.000875       0  0.005752
# 72031050111      0.00   0.000000       0  0.000000
# 72127008603      0.00   0.000000       0  0.004710
# 72043954200      1.26   0.000000       1  0.010005
# 72063210300      2.78   0.170208       0  0.004757
# 72127003501      0.00   0.487420       2  0.044343
# 72101955202      0.00   0.003924       3  0.061192
# 72103170200      1.68   0.018834       0  0.002595
# 72091570300      0.81   0.075737       1  0.011680
# 72029100504      2.00   0.121348       2  0.027628
# 72127008602      0.88   0.000000       0  0.001211
# 72061040103      0.00   0.000044       3  0.053726
# 72153750602      2.55   0.000000       0  0.000000
# 72137120600      0.61   0.000000       2  0.037406
# 72121960700      0.00   0.029668       0  0.000000
# 72011810600      7.03   0.010375       1  0.010036
#
# [705 rows x 11 columns]

# %%
def merge_class_results(x_train,x_test,y_train,y_test):
    df_y_test_pred = pd.DataFrame(y_test)
    df_y_test_pred['cat_4q_pred'] = pred_test

    df_y_train_pred = pd.DataFrame(y_train)
    df_y_train_pred['cat_4q_pred'] = pred_train
    
    df_class_results = df_y_train_pred.append(df_y_test_pred)
    df_class_results.drop(['cat_4q'], axis=1, inplace=True)
    
    df_master_results = df_master.merge(df_class_results, right_index=True, left_index=True, how='left')
    df_master_results.drop(['O_Ind', 'R_I_No0', 'R_I_NoO', 'R_I_No0_NoO', 'cat_3q','R_DES', 'R_AFF', 'Ex_Q4_c'], axis=1, inplace=True)
    
    return df_master_results

# %%
#EXAMPLE
df_master_results = merge_class_results(x_train,x_test,y_train,y_test)

# %% [markdown]
# ### Divide into 2 sets for 2 regressions: bottom 3 quartiles and top quartile

# %%
def split_class_results(df_master_results):
    df_master_low = df_master_results[df_master_results['cat_4q_pred'] < 3]
    df_master_high = df_master_results[df_master_results['cat_4q_pred'] == 3]
    
    return df_master_low, df_master_high

# %%
#EXAMPLE
df_master_low, df_master_high = split_class_results(df_master_results)

# %%
# EXAMPLE:
#Consider keeping 'cat_4q' in low model for stratified sampling
feature_list = ['PropSFHA', 'PropDG', 'AveLS', 'HurTrack',
                'PeakGust', 'StrVI', 'SeVI', 'AveDepth', 'PropSComm']
target_list = ['R_Ind']

df_low = choose_data(df_master_low, feature_list, target_list)

# %%
# EXAMPLE:
feature_list = ['PropSFHA', 'PropDG', 'AveLS', 'HurTrack',
                'PeakGust', 'StrVI', 'SeVI', 'AveDepth', 'PropSComm']
target_list = ['R_Ind']

df_high = choose_data(df_master_high, feature_list, target_list)

# %%
# EXAMPLE:
target_str = 'R_Ind'
y_low, df_x_low = partition_data(df_low, target_str)

# %%
# EXAMPLE:
target_str = 'R_Ind'
y_high, df_x_high = partition_data(df_high, target_str)

# %%
def split_the_data_stratify_2(df_x, y):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y, 
                                                        test_size=0.2, 
                                                        random_state=42,
                                                        stratify = df_master_low['cat_4q'])
    return x_train, x_test, y_train, y_test

# %%
# Careful of Random State
# Change y_binned to y if categorical
# EXAMPLE:
x_train_l, x_test_l, y_train_l, y_test_l = split_the_data_stratify_2(df_x_low, y_low)

# %%
# Careful of Random State
# Change y_binned to y if categorical
# EXAMPLE:
x_train_h, x_test_h, y_train_h, y_test_h = split_the_data(df_x_high, y_high)

# %% [markdown]
# ### Eventually wanted to tune here too

# %%
def run_regression(x_train, y_train):
    reg_model = RandomForestRegressor(random_state=42, n_estimators=1500, min_samples_split=8, 
                                      max_depth = 100, max_features=2, min_samples_leaf=1) 
    reg_model.fit(x_train, y_train)
    return reg_model

# %%
# EXAMPLE
# Careful of Random State
reg_model_l = run_regression(x_train_l, y_train_l)

# %%
# EXAMPLE
# Careful of Random State
reg_model_h = run_regression(x_train_h, y_train_h)

# %%
# EXAMPLE
#CHOOSE MODEL
pred_train_l, pred_test_l = prediction(reg_model_l, x_train_l, x_test_l)

# %%
# EXAMPLE
#CHOOSE MODEL
pred_train_h, pred_test_h = prediction(reg_model_h, x_train_h, x_test_h)

# %%
def evaluate_regression(pred_train, pred_test, y_train, y_test):
    r_train = r2_score(y_train, pred_train)
    print('The training r-squared score is {}'.format(r_train))
    r_test = r2_score(y_test, pred_test)
    print('The testing r-squared score is {}'.format(r_test))
    meanabserrors_train = np.mean(abs(pred_train - y_train))
    print('The training mean absolute error is {}'.format(meanabserrors_train))
    meanabserrors_test = np.mean(abs(pred_test - y_test))
    print('The testing mean absolute error is {}'.format(meanabserrors_test))
    rmse = math.sqrt(mean_squared_error(y_test, pred_test))
    print('The root mean square error is {}'.format(rmse))
    mse = mean_squared_error(y_test, pred_test)
    print('The mean square error is {}'.format(mse))
    errors = pred_test - y_test
    meanerror = np.mean(errors)
    print('The mean error is {}'.format(meanerror))
    return errors

# %%
# EXAMPLE
errors_l = evaluate_regression(pred_train_l, pred_test_l, y_train_l, y_test_l)
# Out:
# The training r-squared score is 0.7012948268389854
# The testing r-squared score is 0.1478185772624212
# The training mean absolute error is 0.00664184467871141
# The testing mean absolute error is 0.011542304256728572
# The root mean square error is 0.017254652350883592
# The mean square error is 0.0002977230277498526
# The mean error is -0.001521590267890268

# %%
# EXAMPLE
errors_h = evaluate_regression(pred_train_h, pred_test_h, y_train_h, y_test_h)
# Out:
# The training r-squared score is 0.6453201013727623
# The testing r-squared score is -0.11840833041527477
# The training mean absolute error is 0.01898320347250457
# The testing mean absolute error is 0.029053042651220804
# The root mean square error is 0.04091336474454104
# The mean square error is 0.0016739034147198535
# The mean error is -0.008879948851157166

# %%
def plot_predictions(y_test, pred, Title):
    df_predictions = pd.DataFrame(y_test)
    df_predictions['Pred'] = pred
    X = df_predictions.iloc[:, 0].values.reshape(-1, 1)
    Y = df_predictions.iloc[:, 1].values.reshape(-1, 1)
    fig, ax = plt.subplots()
    ax.scatter(X, Y, color='maroon')
    line = mlines.Line2D([0, 1], [0, 1], color='orange')
    transform = ax.transAxes
    line.set_transform(transform)
    ax.add_line(line)
    ax.set_xlabel(ax.get_xlabel(), fontsize = 18)
    ax.set_ylabel(ax.get_ylabel(), fontsize = 18)
    ax.tick_params(axis='both', which='major', labelsize=15)
    plt.grid(True)
    plt.xlabel("Damage Index")
    plt.ylabel("Precited Damage Index")
    plt.xlim(0, 0.2)
    plt.ylim(0, 0.2)
    plt.title('Model Evaluation -' +  Title, fontsize = 20)
    plt.show()

# %% [markdown]
# ### Why are there mixed values in the low and high sets?????? - Because it is going off of the predictions
# ### Break into 4 maybe? or 3?

# %%
# EXAMPLE
Title = 'Test Set'
plot_predictions(y_test_h, pred_test_h, Title)

# %%
# EXAMPLE
Title = 'Train Set'
plot_predictions(y_train_h, pred_train_h, Title)

# %%
# EXAMPLE
Title = 'Test Set'
plot_predictions(y_test_l, pred_test_l, Title)

# %%
# EXAMPLE
Title = 'Train Set'
plot_predictions(y_train_l, pred_train_l, Title)

# %% [markdown]
# ### Importances

# %%
def calc_gini_importances(x_train, model):
    importances = model.feature_importances_
    importances_df = pd.DataFrame(importances, x_train.columns,
                                  columns=['Importance']).sort_values('Importance',
                                  ascending=False)
    importances_df.reset_index(inplace=True)
    importances_df.rename(columns={'index':'Feature'}, inplace=True)
    return importances_df

# %%
# indicate if reg_model or class_model
# EXAMPLE
df_gini_importances_l = calc_gini_importances(x_train_l, reg_model_l)

# %%
# indicate if reg_model or class_model
# EXAMPLE
df_gini_importances_h = calc_gini_importances(x_train_h, reg_model_h)

# %%
def gini_importance_plot(df_gini_importances):
    df_gini_importances.sort_values('Importance', ascending=False).plot.bar('Feature',
                                                                            'Importance', 
                                                                            color='maroon', 
                                                                            legend = False)
    plt.title("Feature Importances", fontsize = 25)
    plt.ylabel('Importance', fontsize = 16)
    plt.xlabel('')
    plt.xticks(fontsize = 16, rotation = 45, ha='right')
    plt.yticks(fontsize = 14)

# %%
# EXAMPLE
gini_importance_plot(df_gini_importances_l)

# %%
gini_importance_plot(df_gini_importances_h)
