# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import pyexcel_xlsx
# %pylab inline
#%matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

from pandas.plotting import scatter_matrix
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (15, 10)
matplotlib.rcParams.update({'font.size': 25,'legend.fontsize':25, 'lines.markersize' : 15, 'xtick.labelsize': 20, 'ytick.labelsize': 20 })#,'font.family': 'serif'})
rc('axes', linewidth=3)
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import AutoMinorLocator

# %%
data = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/master_df_20191021.xlsx")
df = pd.DataFrame(data)
df = df.set_index(['FIPS'])
df.drop(['cat_3q', 'cat_4q','O_Ind', 'R_I_No0_NoO', 'R_I_NoO', 'R_Ind'], axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#              Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# FIPS
# 72001956400        0.03        0.02        2.00        2.72        0.27
# 72001956500        0.01        0.00        1.88        0.00        0.29
# 72001956800        0.01        0.00        1.96        0.00        0.26
# 72003430100        0.56        0.52        1.17        6.64        0.27
# 72003430200        0.38        0.43        1.00        4.51        0.27
#
#              PeakGust_1  MaxSusta_1  Count_  StrVI   SeVI  Str+SeVI   SoVI  \
# FIPS
# 72001956400       43.81       33.98    1854   7.84  -7.49      0.35 -14.31
# 72001956500       43.36       33.98    1833   5.42 -13.13     -7.71  -8.48
# 72001956800       43.81       33.98    2528   5.90  -5.07      0.84  -8.41
# 72003430100       38.00       30.40    2369   4.36   4.08      8.44  -0.53
# 72003430200       38.00       30.40    2141   6.97  11.14     18.11  -0.03
#
#              DG_mean_m   R_I_No0
# FIPS
# 72001956400       2.57  0.017260
# 72001956500       0.00  0.007092
# 72001956800       0.00  0.028481
# 72003430100       2.26  0.036724
# 72003430200       3.00  0.017749

# %%
scatter_matrix = scatter_matrix(df, c=df['R_Ind'], figsize = [20,20])
for ax in scatter_matrix.ravel():
    ax.set_xlabel(ax.get_xlabel(), fontsize = 12, rotation = 45)
    ax.set_ylabel(ax.get_ylabel(), fontsize = 12, rotation = 45)

# %%
hm = sns.heatmap(df.corr(method = 'spearman'),
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15})

plt.show()

# %%
#df.describe()

# %%
#boxplot = df.boxplot(column=['Prop_SFHA_', 'Prop_DG_Ar'])

# %%
#boxplot = df.boxplot(column=['DG_MaxDe_1'])

# %%
#boxplot = df.boxplot(column=['HurTrack_D'])

# %%
#boxplot = df.boxplot(column=['PeakGust_1', 'MaxSusta_1'])

# %%
#boxplot = df.boxplot(column=['StrVI', 'SeVI', 'Str+SeVI', 'SoVI'])

# %%
for col in df.columns:
    print(col)
# Out:
# Prop_SFHA_
# Prop_DG_Ar
# Ave_LS_cod
# DG_MaxDe_1
# HurTrack_D
# PeakGust_1
# MaxSusta_1
# Count_
# StrVI
# SeVI
# Str+SeVI
# SoVI
# DG_mean_m
# R_Ind

# %% [markdown]
# ## This plot is a correlation matrix, show's Pearson Product Moment Correlation Coeffcient, aka "Pearson's r", linear dependence b/w pairs of features. -1 = perfectly negatively correlated, 0 is no correlation, 1 is perfectly positively correlated

# %%
cols = ['Prop_SFHA_','Prop_DG_Ar','Ave_LS_cod','DG_MaxDe_1','HurTrack_D','PeakGust_1','MaxSusta_1','Count_','StrVI','SeVI','Str+SeVI','SoVI', 'DG_mean_m', "R_Ind"]
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15},
                yticklabels = cols,
                xticklabels = cols)
plt.show()

# %% [markdown]
# ## Table of Pearson correlations

# %%
df.corr(method = 'pearson')
# Out:
#             Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# Prop_SFHA_    1.000000    0.377799   -0.249292    0.058723    0.246497
# Prop_DG_Ar    0.377799    1.000000   -0.111547    0.313675   -0.008071
# Ave_LS_cod   -0.249292   -0.111547    1.000000    0.128376   -0.226766
# DG_MaxDe_1    0.058723    0.313675    0.128376    1.000000   -0.118603
# HurTrack_D    0.246497   -0.008071   -0.226766   -0.118603    1.000000
# PeakGust_1   -0.024920   -0.087815   -0.168908   -0.122414   -0.422403
# MaxSusta_1   -0.006532   -0.067151   -0.188781   -0.128000   -0.413260
# Count_       -0.187096   -0.007932    0.179523    0.233414   -0.127481
# StrVI        -0.141360    0.036643    0.215025    0.231299   -0.159025
# SeVI         -0.115384    0.020860    0.002528    0.022922   -0.098203
# Str+SeVI     -0.179815    0.038944    0.127624    0.154249   -0.175640
# SoVI         -0.048664   -0.017294   -0.035462   -0.051703   -0.095987
# DG_mean_m     0.105462    0.381298    0.155926    0.814829   -0.083345
# R_Ind         0.039645    0.059920    0.076314    0.166542   -0.210535
#
#             PeakGust_1  MaxSusta_1    Count_     StrVI      SeVI  Str+SeVI  \
# Prop_SFHA_   -0.024920   -0.006532 -0.187096 -0.141360 -0.115384 -0.179815
# Prop_DG_Ar   -0.087815   -0.067151 -0.007932  0.036643  0.020860  0.038944
# Ave_LS_cod   -0.168908   -0.188781  0.179523  0.215025  0.002528  0.127624
# DG_MaxDe_1   -0.122414   -0.128000  0.233414  0.231299  0.022922  0.154249
# HurTrack_D   -0.422403   -0.413260 -0.127481 -0.159025 -0.098203 -0.175640
# PeakGust_1    1.000000    0.997301 -0.300541 -0.352692  0.081706 -0.136759
# MaxSusta_1    0.997301    1.000000 -0.308262 -0.362688  0.070239 -0.152267
# Count_       -0.300541   -0.308262  1.000000  0.478882  0.218031  0.463302
# StrVI        -0.352692   -0.362688  0.478882  1.000000 -0.053245  0.538318
# SeVI          0.081706    0.070239  0.218031 -0.053245  1.000000  0.812883
# Str+SeVI     -0.136759   -0.152267  0.463302  0.538318  0.812883  1.000000
# SoVI          0.273479    0.261577  0.065616 -0.293377  0.748472  0.460553
# DG_mean_m    -0.147610   -0.153598  0.237795  0.249731  0.044607  0.183314
# R_Ind         0.086038    0.092276  0.110573  0.188350 -0.204946 -0.063108
#
#                 SoVI  DG_mean_m     R_Ind
# Prop_SFHA_ -0.048664   0.105462  0.039645
# Prop_DG_Ar -0.017294   0.381298  0.059920
# Ave_LS_cod -0.035462   0.155926  0.076314
# DG_MaxDe_1 -0.051703   0.814829  0.166542
# HurTrack_D -0.095987  -0.083345 -0.210535
# PeakGust_1  0.273479  -0.147610  0.086038
# MaxSusta_1  0.261577  -0.153598  0.092276
# Count_      0.065616   0.237795  0.110573
# StrVI      -0.293377   0.249731  0.188350
# SeVI        0.748472   0.044607 -0.204946
# Str+SeVI    0.460553   0.183314 -0.063108
# SoVI        1.000000  -0.035630 -0.206325
# DG_mean_m  -0.035630   1.000000  0.163085
# R_Ind      -0.206325   0.163085  1.000000

# %% [markdown]
# ## Table of Spearman Correlations

# %% [markdown]
# The difference between standard Pearson’s correlation is that this one first transforms variables into ranks and only then runs Pearson’s correlation on the ranks.
#
# Spearman’s correlation:
# - is nonparametric
# - does not assume a linear relationship between variables
# - it looks for monotonic relationships

# %%
df.corr(method = 'spearman')
# Out:
#             Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# Prop_SFHA_    1.000000    0.414889   -0.261651    0.282260    0.252505
# Prop_DG_Ar    0.414889    1.000000   -0.023385    0.842642   -0.110686
# Ave_LS_cod   -0.261651   -0.023385    1.000000    0.123787   -0.216424
# DG_MaxDe_1    0.282260    0.842642    0.123787    1.000000   -0.177224
# HurTrack_D    0.252505   -0.110686   -0.216424   -0.177224    1.000000
# PeakGust_1   -0.036746   -0.130986   -0.235558   -0.196178   -0.176341
# MaxSusta_1   -0.016929   -0.106624   -0.257391   -0.187316   -0.172786
# Count_       -0.114124    0.163161    0.245249    0.329499   -0.209203
# StrVI        -0.114157    0.139643    0.236938    0.247833   -0.234549
# SeVI         -0.060582    0.011173    0.018579    0.003743   -0.103064
# Str+SeVI     -0.143904    0.079041    0.164549    0.148759   -0.228215
# SoVI         -0.059782   -0.014966   -0.020874   -0.047834   -0.088726
# DG_mean_m     0.276054    0.824889    0.135707    0.980880   -0.169130
# R_Ind         0.028139    0.127553    0.058510    0.169587   -0.218276
#
#             PeakGust_1  MaxSusta_1    Count_     StrVI      SeVI  Str+SeVI  \
# Prop_SFHA_   -0.036746   -0.016929 -0.114124 -0.114157 -0.060582 -0.143904
# Prop_DG_Ar   -0.130986   -0.106624  0.163161  0.139643  0.011173  0.079041
# Ave_LS_cod   -0.235558   -0.257391  0.245249  0.236938  0.018579  0.164549
# DG_MaxDe_1   -0.196178   -0.187316  0.329499  0.247833  0.003743  0.148759
# HurTrack_D   -0.176341   -0.172786 -0.209203 -0.234549 -0.103064 -0.228215
# PeakGust_1    1.000000    0.993545 -0.381611 -0.389492  0.102239 -0.156012
# MaxSusta_1    0.993545    1.000000 -0.390894 -0.401220  0.092986 -0.172924
# Count_       -0.381611   -0.390894  1.000000  0.478140  0.196452  0.482302
# StrVI        -0.389492   -0.401220  0.478140  1.000000 -0.131789  0.476410
# SeVI          0.102239    0.092986  0.196452 -0.131789  1.000000  0.768326
# Str+SeVI     -0.156012   -0.172924  0.482302  0.476410  0.768326  1.000000
# SoVI          0.239589    0.231551  0.074673 -0.320226  0.754726  0.448160
# DG_mean_m    -0.192996   -0.184902  0.314984  0.237880 -0.002780  0.134542
# R_Ind        -0.006846    0.010500  0.207772  0.227299 -0.173706 -0.031306
#
#                 SoVI  DG_mean_m     R_Ind
# Prop_SFHA_ -0.059782   0.276054  0.028139
# Prop_DG_Ar -0.014966   0.824889  0.127553
# Ave_LS_cod -0.020874   0.135707  0.058510
# DG_MaxDe_1 -0.047834   0.980880  0.169587
# HurTrack_D -0.088726  -0.169130 -0.218276
# PeakGust_1  0.239589  -0.192996 -0.006846
# MaxSusta_1  0.231551  -0.184902  0.010500
# Count_      0.074673   0.314984  0.207772
# StrVI      -0.320226   0.237880  0.227299
# SeVI        0.754726  -0.002780 -0.173706
# Str+SeVI    0.448160   0.134542 -0.031306
# SoVI        1.000000  -0.056724 -0.169573
# DG_mean_m  -0.056724   1.000000  0.169261
# R_Ind      -0.169573   0.169261  1.000000

# %%
hm = sns.heatmap(df.corr(method = 'spearman'),
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15},
                yticklabels = cols,
                xticklabels = cols)
plt.show()

# %% [markdown]
# ## Add in Mean DG Value

# %%
data2 = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/DG_Zonal_Stats.xlsx")
df_DG = pd.DataFrame(data2)

# %%
for col in df_DG.columns:
    print(col)
# Out:
# Rowid_
# FIPS
# ZONE_CODE
# COUNT
# AREA
# MIN
# MAX
# RANGE
# MEAN
# STD
# SUM

# %%
df_DG.head()
# Out:
#    Rowid_         FIPS  ZONE_CODE   COUNT          AREA       MIN        MAX  \
# 0     NaN  72097081512          1  317767  8.551039e+07  0.000843  32.123077
# 1     NaN  72023830102          6  258934  6.967856e+07  0.000076  31.494505
# 2     NaN  72023830200          7  193271  5.200880e+07  0.000072  28.303806
# 3     NaN  72023830300          8    1975  5.314681e+05  0.001213   4.896801
# 4     NaN  72023830400          9   91323  2.457482e+07  0.000408  30.329470
#
#        RANGE       MEAN       STD           SUM
# 0  32.122234  23.794818  3.718644  7.561208e+06
# 1  31.494429  16.557520  5.728721  4.287305e+06
# 2  28.303734  11.823447  6.960121  2.285129e+06
# 3   4.895588   1.453788  1.015288  2.871232e+03
# 4  30.329062  14.759861  8.525876  1.347915e+06

# %%
df_DG = df_DG.set_index(['FIPS'])

# %%
df_DG.head()
# Out:
#              Rowid_  ZONE_CODE   COUNT          AREA       MIN        MAX  \
# FIPS
# 72097081512     NaN          1  317767  8.551039e+07  0.000843  32.123077
# 72023830102     NaN          6  258934  6.967856e+07  0.000076  31.494505
# 72023830200     NaN          7  193271  5.200880e+07  0.000072  28.303806
# 72023830300     NaN          8    1975  5.314681e+05  0.001213   4.896801
# 72023830400     NaN          9   91323  2.457482e+07  0.000408  30.329470
#
#                  RANGE       MEAN       STD           SUM
# FIPS
# 72097081512  32.122234  23.794818  3.718644  7.561208e+06
# 72023830102  31.494429  16.557520  5.728721  4.287305e+06
# 72023830200  28.303734  11.823447  6.960121  2.285129e+06
# 72023830300   4.895588   1.453788  1.015288  2.871232e+03
# 72023830400  30.329062  14.759861  8.525876  1.347915e+06

# %%
df2 = df.join(df_DG)

# %%
for col in df2.columns:
    print(col)
# Out:
# Prop_SFHA_
# Prop_DG_Ar
# Ave_LS_cod
# DG_MaxDe_1
# HurTrack_D
# PeakGust_1
# MaxSusta_1
# DMG_Index
# Count_
# StrVI
# SeVI
# Str+SeVI
# SoVI
# Rowid_
# ZONE_CODE
# COUNT
# AREA
# MIN
# MAX
# RANGE
# MEAN
# STD
# SUM

# %%
df2 = df2.drop(['Rowid_','ZONE_CODE','COUNT','AREA','MIN','MAX','RANGE','STD','SUM'], axis=1)

# %%
df2.head()
# Out:
#              Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# FIPS
# 72001956300        0.02        0.00        2.00        0.00        0.24
# 72001956400        0.03        0.02        2.00        2.72        0.27
# 72001956500        0.01        0.00        1.88        0.00        0.29
# 72001956600        0.05        0.00        1.80        0.00        0.26
# 72001956700        0.10        0.00        2.00        0.00        0.26
#
#              PeakGust_1  MaxSusta_1  DMG_Index  Count_  StrVI   SeVI  \
# FIPS
# 72001956300       44.26       34.87       0.01    2414   3.07  -8.41
# 72001956400       43.81       33.98       1.78    1854   7.84  -7.49
# 72001956500       43.36       33.98       0.71    1833   5.42 -13.13
# 72001956600       43.81       34.42       0.01     698   1.21  -7.72
# 72001956700       43.81       34.42       0.01     790   1.30  -6.66
#
#              Str+SeVI   SoVI      MEAN
# FIPS
# 72001956300     -5.35  -9.44       NaN
# 72001956400      0.35 -14.31  8.427649
# 72001956500     -7.71  -8.48       NaN
# 72001956600     -6.51  -7.78       NaN
# 72001956700     -5.35  -6.12       NaN

# %%
df2.MEAN.fillna(0, inplace=True)

# %%
df2.rename(columns={"MEAN":"DG_mean"}, inplace=True)

# %%
df2['DG_mean_m'] = df2.DG_mean.values / 3.2808

# %%
df2
# Out:
#              Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# FIPS
# 72001956300        0.02        0.00        2.00        0.00        0.24
# 72001956400        0.03        0.02        2.00        2.72        0.27
# 72001956500        0.01        0.00        1.88        0.00        0.29
# 72001956600        0.05        0.00        1.80        0.00        0.26
# 72001956700        0.10        0.00        2.00        0.00        0.26
# 72001956800        0.01        0.00        1.96        0.00        0.26
# 72003430100        0.56        0.52        1.17        6.64        0.27
# 72003430200        0.38        0.43        1.00        4.51        0.27
# 72003430300        0.20        0.00        1.00        0.00        0.29
# 72003430401        0.01        0.00        1.50        0.00        0.29
# 72003430402        0.01        0.00        2.00        0.00        0.29
# 72003430501        0.06        0.00        1.20        0.00        0.30
# 72003430502        0.00        0.00        1.70        0.00        0.32
# 72003430601        0.01        0.00        1.22        0.00        0.32
# 72003430602        0.49        0.00        0.88        0.00        0.31
# 72005400100        0.02        0.00        0.71        0.00        0.14
# 72153750501      7.39  13.22   0.000000   0.000000
# 72153750502      3.78  11.72   0.000000   0.000000
# 72153750503     -0.28   1.27   1.838396   0.560350
# 72153750601      1.70   4.60   9.039878   2.755388
# 72153750602      3.31   3.91   8.353832   2.546279
#
# [882 rows x 15 columns]

# %%
df2 = df2.round(2)

# %%
df2 = df2.drop(['DG_mean'], axis=1)

# %%
df2.head()
# Out:
#              Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# FIPS
# 72001956300        0.02        0.00        2.00        0.00        0.24
# 72001956400        0.03        0.02        2.00        2.72        0.27
# 72001956500        0.01        0.00        1.88        0.00        0.29
# 72001956600        0.05        0.00        1.80        0.00        0.26
# 72001956700        0.10        0.00        2.00        0.00        0.26
#
#              PeakGust_1  MaxSusta_1  DMG_Index  Count_  StrVI   SeVI  \
# FIPS
# 72001956300       44.26       34.87       0.01    2414   3.07  -8.41
# 72001956400       43.81       33.98       1.78    1854   7.84  -7.49
# 72001956500       43.36       33.98       0.71    1833   5.42 -13.13
# 72001956600       43.81       34.42       0.01     698   1.21  -7.72
# 72001956700       43.81       34.42       0.01     790   1.30  -6.66
#
#              Str+SeVI   SoVI  DG_mean_m
# FIPS
# 72001956300     -5.35  -9.44       0.00
# 72001956400      0.35 -14.31       2.57
# 72001956500     -7.71  -8.48       0.00
# 72001956600     -6.51  -7.78       0.00
# 72001956700     -5.35  -6.12       0.00

# %% [markdown]
# Pearson Correlation Matrix
#
# -1 = perfectly negatively correlated \
# 0 = no correlation \
# 1 = perfectly positively correlated \
#
# Assumes linearity and normal and parametric though

# %%
cols = ['Prop_SFHA_','Prop_DG_Ar','Ave_LS_cod','DG_MaxDe_1', 'DG_mean_m','HurTrack_D','PeakGust_1','MaxSusta_1','Count_','StrVI','SeVI','Str+SeVI','SoVI', 'DMG_Index']
cm = np.corrcoef(df2[cols].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15},
                yticklabels = cols,
                xticklabels = cols)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-ccbac34d6ca4> in <module>()
#       1 cols = ['Prop_SFHA_','Prop_DG_Ar','Ave_LS_cod','DG_MaxDe_1', 'DG_mean_m','HurTrack_D','PeakGust_1','MaxSusta_1','Count_','StrVI','SeVI','Str+SeVI','SoVI', 'DMG_Index']
# ----> 2 cm = np.corrcoef(df2[cols].values.T)
#       3 sns.set(font_scale=1.5)
#       4 hm = sns.heatmap(cm,
#       5                 cbar=True,
#
# NameError: name 'df2' is not defined

# %%
scatter_matrix = scatter_matrix(df2, c=df2['DMG_Index'], figsize = [20,20])
for ax in scatter_matrix.ravel():
    ax.set_xlabel(ax.get_xlabel(), fontsize = 12, rotation = 45)
    ax.set_ylabel(ax.get_ylabel(), fontsize = 12, rotation = 90)

# %% [markdown]
# # Export to Excel

# %%
df2 = df2.drop(['DMG_Index'], axis=1)

# %%
df2
# Out:
#              Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# FIPS
# 72001956300        0.02        0.00        2.00        0.00        0.24
# 72001956400        0.03        0.02        2.00        2.72        0.27
# 72001956500        0.01        0.00        1.88        0.00        0.29
# 72001956600        0.05        0.00        1.80        0.00        0.26
# 72001956700        0.10        0.00        2.00        0.00        0.26
# 72001956800        0.01        0.00        1.96        0.00        0.26
# 72003430100        0.56        0.52        1.17        6.64        0.27
# 72003430200        0.38        0.43        1.00        4.51        0.27
# 72003430300        0.20        0.00        1.00        0.00        0.29
# 72003430401        0.01        0.00        1.50        0.00        0.29
# 72003430402        0.01        0.00        2.00        0.00        0.29
# 72003430501        0.06        0.00        1.20        0.00        0.30
# 72003430502        0.00        0.00        1.70        0.00        0.32
# 72003430601        0.01        0.00        1.22        0.00        0.32
# 72003430602        0.49        0.00        0.88        0.00        0.31
# 72005400100        0.02        0.00        0.71        0.00        0.14
# 72005400300        0.05        0.00        0.62        0.00        0.16
# 72005400400        0.01        0.00        1.00        0.00        0.19
# 72005400501        0.00        0.00        1.00        0.00        0.18
# 72005400502        0.00        0.00        1.00        0.00        0.19
# 72005400600        0.00        0.00        1.00        0.00        0.21
# 72005400700        0.01        0.00        1.00        5.59        0.21
# 72005400800        0.12        0.36        1.00        7.44        0.22
# 72005400900        0.00        0.00        1.00        0.00        0.22
# 72005401000        0.57        0.73        1.00        7.37        0.23
# 72005401100        0.94        0.95        1.00        6.75        0.24
# 72005401200        0.16        0.16        1.09        6.57        0.23
# 72005401301        0.00        0.00        1.00        0.00        0.20
# 72005401302        0.00        0.00        1.00        0.00        0.16
# 72005401401        0.00        0.00        1.00        0.00        0.16
# ...                 ...         ...         ...         ...         ...
# 72145560801        0.00        0.00        1.00        0.00        0.11
# 72145560802        0.00        0.00        0.78        0.00        0.09
# 72145560900        0.00        0.00        1.12        0.00        0.07
# 72147950500        0.10        0.00        0.00        0.00        0.28
# 72147950600        0.09        0.00        0.00        0.00        0.35
# 72149720100        0.07        0.05        1.22       13.36        0.17
# 72149720300        0.05        0.05        1.00        9.47        0.20
# 72149720400        0.14        0.00        1.00        0.00        0.19
# 72149720502        0.08        0.09        1.00       34.11        0.23
# 72149720503        0.01        0.00        1.56        0.00        0.17
# 72149720504        0.00        0.00        1.56        6.51        0.19
# 72151950600        0.18        0.19        1.00        4.84        0.10
# 72151950700        0.02        0.00        1.61        2.41        0.03
# 72151950800        0.39        0.31        1.14        6.32        0.05
# 72151950900        0.06        0.04        1.13        3.96        0.09
# 72151951000        0.41        0.47        1.00        5.45        0.06
# 72151951100        0.00        0.09        1.00        3.72        0.05
# 72151951200        0.22        0.17        1.22        6.25        0.03
# 72151951300        0.46        0.45        0.94        5.17        0.06
# 72153750101        0.00        0.00        1.83        7.06        0.35
# 72153750102        0.02        0.01        1.36        7.06        0.41
# 72153750201        0.03        0.03        1.67        7.13        0.40
# 72153750202        0.01        0.00        1.20        1.97        0.42
# 72153750300        0.07        0.00        1.00        0.00        0.44
# 72153750400        0.33        0.15        1.00        6.45        0.44
# 72153750501        0.00        0.00        1.00        0.00        0.45
