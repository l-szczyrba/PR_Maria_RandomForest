# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Import Features Dataframe (df_features)

# %%
data = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/AllFeatures20191021.xlsx")
df_features = pd.DataFrame(data)
df_features = df_features.set_index(['FIPS'])

#df_features.drop('DMG_Index',axis=1, inplace=True)

# %% [markdown]
# # Import Target Data Frames

# %% [markdown]
# df_origs = Original targets, index with destroyed weighted 2x and straight ratio of affected and destroyed
#
# df_No0 = Straight ratio with dropped 0 values
#
# df_NoO = Straight ratio with dropped outliers
#
# df_No0_NoO = Ratio with bboth 0 values and outliers dropped
#
# df_cat = Categorical values, one with 3 (0:low, 1:medium, 2:high) and one with 4 (0:low, 1:medium-low, 2:medium-high, 3:high)

# %%
origs = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/origs.xlsx")
df_origs = pd.DataFrame(origs)
df_origs = df_origs.set_index(['FIPS'])

No0 = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/No0.xlsx")
df_No0 = pd.DataFrame(No0)
df_No0 = df_No0.set_index(['FIPS'])

NoO = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/NoO.xlsx")
df_NoO = pd.DataFrame(NoO)
df_NoO = df_NoO.set_index(['FIPS'])

No0_NoO = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/No0_NoO.xlsx")
df_No0_NoO = pd.DataFrame(No0_NoO)
df_No0_NoO = df_No0_NoO.set_index(['FIPS'])

cat = pd.read_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/cat.xlsx")
df_cat = pd.DataFrame(cat)
df_cat = df_cat.set_index(['FIPS'])

# %%
#frames = ['df_origs', 'df_No0', 'df_NoO', 'df_No0_NoO', 'df_cat']
# merged = []
# for i in frames:
#     df_features.merge(i, right_index=True, left_index=True, how='left')

# %%
master_df = df_features.merge(df_origs, right_index=True, left_index=True, how='left') \
.merge(df_No0, right_index = True, left_index=True, how='left') \
.merge(df_NoO, right_index = True, left_index=True, how='left') \
.merge(df_No0_NoO, right_index=True, left_index=True, how='left') \
.merge(df_cat, right_index=True, left_index=True, how='left')

# %%
master_df.to_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/master_df_20191021.xlsx")

# %%
master_df
# Out:
#              Prop_SFHA_  Prop_DG_Ar  Ave_LS_cod  DG_MaxDe_1  HurTrack_D  \
# FIPS
# 72001956300        0.02        0.00        2.00        0.00        0.24
# 72001956400        0.03        0.02        2.00        2.72        0.27
# 72001956500        0.01        0.00        1.88        0.00        0.29
# 72001956600        0.05        0.00        1.80        0.00        0.26
# 72001956700        0.10        0.00        2.00        0.00        0.26
# 72001956800        0.01        0.00        1.96        0.00        0.26
# 72003430100        0.56        0.52        1.17        6.64        0.27
# 72003430200        0.38        0.43        1.00        4.51        0.27
# 72003430300        0.20        0.00        1.00        0.00        0.29
# 72003430401        0.01        0.00        1.50        0.00        0.29
# 72003430402        0.01        0.00        2.00        0.00        0.29
# 72003430501        0.06        0.00        1.20        0.00        0.30
# 72003430502        0.00        0.00        1.70        0.00        0.32
# 72003430601        0.01        0.00        1.22        0.00        0.32
# 72003430602        0.49        0.00        0.88        0.00        0.31
# 72005400100        0.02        0.00        0.71        0.00        0.14
# 72005400300        0.05        0.00        0.62        0.00        0.16
# 72005400400        0.01        0.00        1.00        0.00        0.19
# 72005400501        0.00        0.00        1.00        0.00        0.18
# 72005400502        0.00        0.00        1.00        0.00        0.19
# 72005400600        0.00        0.00        1.00        0.00        0.21
# 72005400700        0.01        0.00        1.00        5.59        0.21
# 72005400800        0.12        0.36        1.00        7.44        0.22
# 72005400900        0.00        0.00        1.00        0.00        0.22
# 72005401000        0.57        0.73        1.00        7.37        0.23
# 72005401100        0.94        0.95        1.00        6.75        0.24
# 72005401200        0.16        0.16        1.09        6.57        0.23
# 72005401301        0.00        0.00        1.00        0.00        0.20
# 72005401302        0.00        0.00        1.00        0.00        0.16
# 72005401401        0.00        0.00        1.00        0.00        0.16
# ...                 ...         ...         ...         ...         ...
# 72145560801        0.00        0.00        1.00        0.00        0.11
# 72145560802        0.00        0.00        0.78        0.00        0.09
# 72145560900        0.00        0.00        1.12        0.00        0.07
# 72147950500        0.10        0.00        0.00        0.00        0.28
# 72147950600        0.09        0.00        0.00        0.00        0.35
# 72149720100        0.07        0.05        1.22       13.36        0.17
# 72149720300        0.05        0.05        1.00        9.47        0.20
# 72149720400        0.14        0.00        1.00        0.00        0.19
# 72149720502        0.08        0.09        1.00       34.11        0.23
# 72149720503        0.01        0.00        1.56        0.00        0.17
# 72149720504        0.00        0.00        1.56        6.51        0.19
# 72151950600        0.18        0.19        1.00        4.84        0.10
# 72151950700        0.02        0.00        1.61        2.41        0.03
# 72151950800        0.39        0.31        1.14        6.32        0.05
# 72151950900        0.06        0.04        1.13        3.96        0.09
# 72151951000        0.41        0.47        1.00        5.45        0.06
# 72151951100        0.00        0.09        1.00        3.72        0.05
# 72151951200        0.22        0.17        1.22        6.25        0.03
# 72151951300        0.46        0.45        0.94        5.17        0.06
# 72153750101        0.00        0.00        1.83        7.06        0.35
# 72153750102        0.02        0.01        1.36        7.06        0.41
# 72153750201        0.03        0.03        1.67        7.13        0.40
# 72153750202        0.01        0.00        1.20        1.97        0.42
# 72153750300        0.07        0.00        1.00        0.00        0.44
# 72153750400        0.33        0.15        1.00        6.45        0.44
# 72153750501        0.00        0.00        1.00        0.00        0.45
# 72153750502        0.00        0.00        1.00        0.00        0.45
# 72153750503        0.10        0.00        1.00        1.52        0.46
# 72153750601        0.23        0.24        1.00        7.65        0.45
# 72153750602        0.10        0.10        1.00        5.62        0.48
#
#              PeakGust_1  MaxSusta_1  Count_  StrVI   SeVI  Str+SeVI   SoVI  \
# FIPS
# 72001956300       44.26       34.87    2414   3.07  -8.41     -5.35  -9.44
# 72001956400       43.81       33.98    1854   7.84  -7.49      0.35 -14.31
# 72001956500       43.36       33.98    1833   5.42 -13.13     -7.71  -8.48
# 72001956600       43.81       34.42     698   1.21  -7.72     -6.51  -7.78
# 72001956700       43.81       34.42     790   1.30  -6.66     -5.35  -6.12
# 72001956800       43.81       33.98    2528   5.90  -5.07      0.84  -8.41
# 72003430100       38.00       30.40    2369   4.36   4.08      8.44  -0.53
# 72147950600       0.00  0.166558  0.119388  0.119388       NaN          NaN
# 72149720100       7.09  0.009886  0.009886  0.009886  0.009886     0.009886
# 72149720300       3.56  0.000000  0.000000       NaN  0.000000          NaN
# 72149720400       0.00  0.000000  0.000000       NaN  0.000000          NaN
# 72149720502       3.52  0.000000  0.000000       NaN  0.000000          NaN
# 72149720503       0.00  0.000000  0.000000       NaN  0.000000          NaN
# 72149720504       2.91  0.000718  0.000718  0.000718  0.000718     0.000718
# 72151950600       1.61  0.027846  0.027540  0.027540  0.027540     0.027540
# 72151950700       0.87  0.050874  0.048967  0.048967  0.048967     0.048967
# 72151950800       1.86  0.065612  0.065147  0.065147  0.065147     0.065147
# 72151950900       1.27  0.029401  0.027967  0.027967  0.027967     0.027967
# 72151951000       1.82  0.004736  0.003946  0.003946  0.003946     0.003946
# 72151951100       0.79  0.011000  0.009000  0.009000  0.009000     0.009000
# 72151951200       1.83  0.039489  0.034262  0.034262  0.034262     0.034262
# 72151951300       2.31  0.045507  0.042422  0.042422  0.042422     0.042422
# 72153750101       4.58  0.071279  0.069706  0.069706  0.069706     0.069706
# 72153750102       2.39  0.012806  0.012806  0.012806  0.012806     0.012806
# 72153750201       5.60  0.039164  0.038120  0.038120  0.038120     0.038120
# 72153750202       0.57  0.006351  0.006351  0.006351  0.006351     0.006351
# 72153750300       0.00  0.000000  0.000000       NaN  0.000000          NaN
# 72153750400       1.48  0.000000  0.000000       NaN  0.000000          NaN
# 72153750501       0.00  0.000000  0.000000       NaN  0.000000          NaN
# 72153750502       0.00  0.000000  0.000000       NaN  0.000000          NaN
# 72153750503       0.56  0.000000  0.000000       NaN  0.000000          NaN
# 72153750601       2.76  0.000000  0.000000       NaN  0.000000          NaN
# 72153750602       2.55  0.000000  0.000000       NaN  0.000000          NaN
#
#              cat_3q  cat_4q
# FIPS
# 72001956300       0       0
# 72001956400       1       1
# 72001956500       0       1
# 72001956600       0       0
# 72001956700       0       0
# 72001956800       1       2
# 72003430100       2       2
# 72003430200       1       1
# 72003430300       1       1
# 72003430401       2       2
# 72003430402       2       3
# 72003430501       1       2
# 72003430502       0       1
# 72003430601       1       1
# 72003430602       1       2
# 72005400100       1       2
# 72005400300       1       1
# 72005400400       1       2
# 72005400501       0       0
# 72005400502       1       1
# 72005400600       1       2
# 72005400700       1       2
# 72005400800       2       2
# 72005400900       2       2
# 72005401000       1       2
# 72005401100       1       1
# 72005401200       1       2
# 72005401301       0       1
# 72005401302       1       1
# 72005401401       1       2
# ...             ...     ...
# 72145560801       2       3
# 72145560802       2       2
# 72145560900       2       3
# 72147950500       2       3
# 72147950600       2       3
# 72149720100       0       1
# 72149720300       0       0
# 72149720400       0       0
# 72149720502       0       0
# 72149720503       0       0
# 72149720504       0       0
# 72151950600       1       2
# 72151950700       2       3
# 72151950800       2       3
# 72151950900       1       2
# 72151951000       0       0
# 72151951100       0       1
# 72151951200       1       2
# 72151951300       2       2
# 72153750101       2       3
# 72153750102       1       1
# 72153750201       2       2
# 72153750202       0       0
# 72153750300       0       0
# 72153750400       0       0
# 72153750501       0       0
# 72153750502       0       0
# 72153750503       0       0
# 72153750601       0       0
# 72153750602       0       0
#
# [882 rows x 20 columns]
