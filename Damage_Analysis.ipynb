# %%
import pandas as pd
from pandas.plotting import scatter_matrix

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = "/Users/lszczyrba/Project_3.6.3/PR_Housing/DamageAnalysis.xlsx"
data = pd.read_excel(file)
df = pd.DataFrame(data).set_index('Comm_Code')

# %%
df
# Out:
#               R_IND
# Comm_Code
# 72001      0.028481
# 72001      0.017260
# 72001      0.007092
# 72001      0.000000
# 72001      0.000000
# 72001      0.000000
# 72003      0.056522
# 72003      0.037580
# 72003      0.036724
# 72003      0.029898
# 72003      0.022069
# 72003      0.020444
# 72003      0.017749
# 72003      0.015252
# 72003      0.011145
# 72005      0.041221
# 72005      0.037588
# 72005      0.034965
# 72005      0.032511
# 72005      0.031589
# 72005      0.030675
# 72005      0.028836
# 72005      0.027712
# 72005      0.022441
# 72005      0.020727
# 72005      0.019824
# 72005      0.016291
# 72005      0.015567
# 72005      0.012697
# 72005      0.007850
# ...             ...
# 72145      0.019882
# 72145      0.009681
# 72145      0.005935
# 72147      0.119388
# 72147      0.083734
# 72149      0.009886
# 72149      0.000718
# 72149      0.000000
# 72149      0.000000
# 72149      0.000000
# 72149      0.000000
# 72151      0.065147
# 72151      0.048967
# 72151      0.042422
# 72151      0.034262
# 72151      0.027967
# 72151      0.027540
# 72151      0.009000
# 72151      0.003946
# 72153      0.069706
# 72153      0.038120
# 72153      0.012806
# 72153      0.006351
# 72153      0.000000
# 72153      0.000000
# 72153      0.000000
# 72153      0.000000
# 72153      0.000000
# 72153      0.000000
# 72153      0.000000
#
# [882 rows x 1 columns]

# %%
DF_statistics = pd.DataFrame(df.groupby('Comm_Code', as_index=True)['R_IND'].mean())

# %%
DF_statistics['max'] = df.groupby('Comm_Code', as_index=True)['R_IND'].max()

# %%
DF_statistics
# Out:
#               R_IND       max
# Comm_Code
# 72001      0.008806  0.028481
# 72003      0.027487  0.056522
# 72005      0.024065  0.041221
# 72007      0.080566  0.110443
# 72009      0.000000  0.000000
# 72011      0.026490  0.078273
# 72013      0.055234  0.153265
# 72015      0.084066  0.167192
# 72017      0.044861  0.074330
# 72019      0.001440  0.008638
# 72021      0.031380  0.197384
# 72023      0.015972  0.047844
# 72025      0.028164  0.106383
# 72027      0.043671  0.076379
# 72029      0.040362  0.188749
# 72031      0.017633  0.081883
# 72033      0.063273  0.161017
# 72035      0.003002  0.026162
# 72037      0.038993  0.056830
# 72039      0.127115  0.153160
# 72041      0.020144  0.050621
# 72043      0.045573  0.124171
# 72045      0.036541  0.080661
# 72047      0.071132  0.135153
# 72049      0.005682  0.005682
# 72051      0.045031  0.059471
# 72053      0.025780  0.055510
# 72054      0.034378  0.058343
# 72055      0.019758  0.039264
# 72057      0.079647  0.134916
# ...             ...       ...
# 72095      0.048329  0.066624
# 72097      0.023060  0.058057
# 72099      0.029536  0.061036
# 72101      0.022613  0.061192
# 72103      0.031044  0.048028
# 72105      0.076543  0.111550
# 72107      0.018238  0.048130
# 72109      0.082556  0.127912
# 72111      0.029792  0.052116
# 72113      0.033155  0.104396
# 72115      0.027335  0.035336
# 72117      0.016671  0.023488
# 72119      0.041035  0.108816
# 72121      0.002991  0.017946
# 72123      0.015067  0.057895
# 72125      0.007771  0.020308
# 72127      0.021900  0.360825
# 72129      0.033671  0.069611
# 72131      0.023252  0.047797
# 72133      0.063077  0.082301
# 72135      0.055437  0.229145
# 72137      0.057508  0.149606
# 72139      0.023688  0.063269
# 72141      0.015839  0.104009
# 72143      0.076790  0.131754
# 72145      0.063160  0.164979
# 72147      0.101561  0.119388
# 72149      0.001767  0.009886
# 72151      0.032406  0.065147
# 72153      0.011544  0.069706
#
# [78 rows x 2 columns]

# %%
df_mean = DF_statistics.sort_values(by=['R_IND'], ascending=False).head(10)

# %%
df_max = DF_statistics.sort_values(by=['max'], ascending=False).head(10)

# %%
df_mean
# Out:
#               R_IND       max
# Comm_Code
# 72039      0.127115  0.153160
# 72147      0.101561  0.119388
# 72015      0.084066  0.167192
# 72109      0.082556  0.127912
# 72007      0.080566  0.110443
# 72057      0.079647  0.134916
# 72143      0.076790  0.131754
# 72105      0.076543  0.111550
# 72047      0.071132  0.135153
# 72033      0.063273  0.161017

# %%
df_mean['label'] = ['Ciales', 'Vieques', 'Arroyo', 'Barranquitas', 'Aguas', 'Guayama', 'Vega Alta', 'Naranjito', 'Corozal', 'Catano']

# %%
df_max
# Out:
#               R_IND       max
# Comm_Code
# 72127      0.021900  0.360825
# 72135      0.055437  0.229145
# 72021      0.031380  0.197384
# 72029      0.040362  0.188749
# 72015      0.084066  0.167192
# 72145      0.063160  0.164979
# 72033      0.063273  0.161017
# 72013      0.055234  0.153265
# 72039      0.127115  0.153160
# 72137      0.057508  0.149606

# %%
df_max['label'] = ['San Juan', 'Toa Alta', 'Bayamon', 'Canovanas', 'Arroyo', 'Vega Baja', 'Catano', 'Arecibo', 'Ciales', 'Toa Baja']

# %%
df_max
# Out:
#               R_IND       max      label
# Comm_Code
# 72127      0.021900  0.360825   San Juan
# 72135      0.055437  0.229145   Toa Alta
# 72021      0.031380  0.197384    Bayamon
# 72029      0.040362  0.188749  Canovanas
# 72015      0.084066  0.167192     Arroyo
# 72145      0.063160  0.164979  Vega Baja
# 72033      0.063273  0.161017     Catano
# 72013      0.055234  0.153265    Arecibo
# 72039      0.127115  0.153160     Ciales
# 72137      0.057508  0.149606   Toa Baja

# %%
df_mean
# Out:
#               R_IND       max         label
# Comm_Code
# 72039      0.127115  0.153160        Ciales
# 72147      0.101561  0.119388       Vieques
# 72015      0.084066  0.167192        Arroyo
# 72109      0.082556  0.127912  Barranquitas
# 72007      0.080566  0.110443         Aguas
# 72057      0.079647  0.134916       Guayama
# 72143      0.076790  0.131754     Vega Alta
# 72105      0.076543  0.111550     Naranjito
# 72047      0.071132  0.135153       Corozal
# 72033      0.063273  0.161017        Catano

# %%
ax = df_mean.sort_values('R_IND', ascending=False).plot.bar('label','R_IND', zorder=3,
                                                                            color='black', 
                                                                            legend = False)
plt.title("", fontsize = 25, fontdict={'horizontalalignment': 'center'})
plt.ylabel('Damage Index (DI1)', fontsize = 18)
plt.xlabel(' ')
plt.xticks(fontsize = 18, rotation = 45, ha='right')
plt.yticks(fontsize = 14)

#ax.grid(zorder=0)

#plt.savefig('F3_MeanDI.pdf', dpi=600, bbox_inches = "tight")

# %%
ax = df_max.sort_values('max', ascending=False).plot.bar('label','max',zorder=3,
                                                                            color='black', 
                                                                            legend = False)
plt.title("", fontsize = 25, fontdict={'horizontalalignment': 'center'})
plt.ylabel('', fontsize = 18)
plt.xlabel(' ')
plt.xticks(fontsize = 18, rotation = 45, ha='right')
plt.yticks(fontsize = 14)

#ax.grid(zorder=0)

plt.savefig('F3_MaxDI.tif', dpi=600, bbox_inches = "tight")
