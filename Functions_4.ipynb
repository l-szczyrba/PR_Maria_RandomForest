# %% [markdown]
# # <span style="color:STEELBLUE">**Set Up**</span>

# %% [markdown]
# ### Import libraries and data

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.cross_validation import ShuffleSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, confusion_matrix, r2_score, classification_report

import math

from collections import defaultdict

# %%
file = "/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/master_df_20191103.xlsx"
data = pd.read_excel(file)
df_master = pd.DataFrame(data).set_index('FIPS')

# %%
print(df_master.columns)
# Out:
# Index(['PropSFHA', 'PropDG', 'AveLS', 'MaxDepth', 'HurTrack', 'PeakGust',
#        'MaxSusta', 'StrVI', 'SeVI', 'Str+SeVI', 'SoVI', 'AveDepth', 'O_Ind',
#        'R_Ind', 'PropSComm', 'R_I_No0', 'R_I_NoO', 'R_I_No0_NoO', 'cat_3q',
#        'cat_4q', 'Count', 'R_DES', 'R_AFF'],
#       dtype='object')

# %% [markdown]
# ### Choose Data

# %%
def choose_data(df_master, feature_list, target_list):
    choices = feature_list + target_list
    df = df_master[choices].copy()
    df.dropna(inplace = True)
    return df

# %%
# EXAMPLE:
feature_list = ['PropSFHA', 'PropDG', 'AveLS', 'HurTrack',
                'PeakGust', 'StrVI', 'SeVI', 'AveDepth', 'PropSComm']
target_list = ['R_Ind']

df = choose_data(df_master, feature_list, target_list)

# %%
df.describe()
# Out:
#          PropSFHA      PropDG       AveLS    HurTrack    PeakGust       StrVI  \
# count  882.000000  882.000000  882.000000  882.000000  882.000000  882.000000
# mean     0.173662    0.058447    1.104161    0.223594   52.697914    0.000533
# std      0.260877    0.159692    0.412690    0.126709    8.664104    3.766862
# min      0.000000    0.000000    0.000000    0.000000   24.590000  -13.150000
# 25%      0.000000    0.000000    1.000000    0.130000   45.150000   -2.635000
# 50%      0.040000    0.000000    1.000000    0.220000   55.880000   -0.190000
# 75%      0.220000    0.020000    1.290000    0.290000   59.900000    2.417500
# max      1.000000    1.000000    3.000000    0.920000   65.710000   16.520000
#
#              SeVI    AveDepth   PropSComm       R_Ind
# count  882.000000  882.000000  882.000000  882.000000
# mean     0.020068    0.982619    0.033592    0.032037
# std      5.450390    1.529905    0.099992    0.035476
# min    -23.740000    0.000000    0.000000    0.000000
# 25%     -3.087500    0.000000    0.000000    0.006897
# 50%      0.630000    0.000000    0.000987    0.022014
# 75%      3.697500    1.760000    0.019027    0.044725
# max     15.220000    9.730000    0.977416    0.360825

# %%
# ### DELETE
# df = df[df.O_Ind != 0]

# %% [markdown]
# # <span style="color:STEELBLUE">**Explore Features**</span>

# %%
def histogram_figure(df_target):
    fig, ax = plt.subplots(1,1,figsize=(6, 4))
    plt.rcParams["patch.force_edgecolor"] = True
    sns.distplot(df_target.values,kde=False)
    fig.text(0.5, 0.02, 'Proportion of Damaged Homes', ha='center', va = 'top', fontsize = 18)
    ax.set_title('Damage Index ', fontsize = 25)
    ax.tick_params(axis='both', which='major', labelsize=15)
#    plt.savefig('targethist_n0.png', dpi=600, bbox_inches = "tight")

# %%
#EXAMPLE:
df_target = df['R_Ind']
histogram_figure(df_target)

# %%
def boxplot_figure(df, target):
    fig, ax = plt.subplots(1,1,figsize=(4, 6))
    ax = df.boxplot(column=target, showfliers=True)
    ax.set_ylabel("Proportion of Damaged Homes", fontsize = 18)
    ax.tick_params(labelsize=15)
    #plt.savefig('boxplot_no0.png', dpi=600, bbox_inches = "tight")

# %%
#EXAMPLE:
target = ['R_Ind']
boxplot_figure(df, target)

# %% [markdown]
# Spearman
#
# In statistics, Spearman's rank correlation coefficient or Spearman's rho, named after Charles Spearman and often denoted by the Greek letter (rho), is a nonparametric measure of rank correlation (statistical dependence between the rankings of two variables). It assesses how well the relationship between two variables can be described using a monotonic function.
#
# The Spearman correlation between two variables is equal to the Pearson correlation between the rank values of those two variables; while Pearson's correlation assesses linear relationships, Spearman's correlation assesses monotonic relationships (whether linear or not). If there are no repeated data values, a perfect Spearman correlation of +1 or −1 occurs when each of the variables is a perfect monotone function of the other.

# %%
def spearman_matrix(df):
    plt.figure(figsize = (9,9))
    hm = sns.heatmap(df.corr(method = 'spearman'),
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15})

# %%
#EXAMPLE:
spearman_matrix(df)

# %%
def feature_matrix(df, target):
    fig = scatter_matrix(df, c=target, figsize = [15,15])
    for ax in fig.ravel():
        ax.set_xlabel(ax.get_xlabel(), fontsize = 12, rotation = 45)
        ax.set_ylabel(ax.get_ylabel(), fontsize = 12, rotation = 45, ha='right')

# %%
#EXAMPLE:
target = df['R_Ind']
feature_matrix(df, target)

# %% [markdown]
# ### Partition and Bin Data

# %%
def partition_data(df, target_str):
    y = df[target_str]
    df_x = df.drop(target_str, axis = 1)
    return y, df_x

# %%
# EXAMPLE:
target_str = 'R_Ind'
y, df_x = partition_data(df, target_str)

# %%
def bin_target(y, n_bins, label):
    y_binned = pd.qcut(y, q=n_bins, labels = label)
    return y_binned

# %%
# EXAMPLE:
y_binned = bin_target(y,4, [0,1,2,3])

# %% [markdown]
# ### Train, Test, Split

# %%
def split_the_data(df_x, y):
    x_train, x_test, y_train, y_test = train_test_split(df_x, y, 
                                                        test_size=0.3, 
                                                        random_state=42,
                                                        stratify = y_binned)
    return x_train, x_test, y_train, y_test

# %%
# Careful of Random State
# Change y_binned to y if categorical
# EXAMPLE:
x_train, x_test, y_train, y_test = split_the_data(df_x, y)

# %%
#histogram_figure(y_train)

# %% [markdown]
# ### Step 1: Randomized Search CV

# %%
def randomized_cv(x_train, y_train, model):
    # Number of trees in random forest
    n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 10)]
    # Number of features to consider at every split
    max_features = ['auto', 'sqrt']
    # Maximum number of levels in tree
    max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
    max_depth.append(None)
    # Minimum number of samples required to split a node
    min_samples_split = [2, 5, 10]
    # Minimum number of samples required at each leaf node
    min_samples_leaf = [1, 2, 4]

    # Create the random grid
    random_grid = {'n_estimators': n_estimators,
                   'max_features': max_features,
                   'max_depth': max_depth,
                   'min_samples_split': min_samples_split,
                   'min_samples_leaf': min_samples_leaf}
    
    # Use the random grid to search for best hyperparameters
    # First create the base model to tune
    rf = model
    # Random search of parameters, using cv = cross validation, 
    # search across 100 different combinations, and use all available cores
    rf_randomized_cv = RandomizedSearchCV(estimator = rf, 
                                          param_distributions = random_grid, 
                                          n_iter = 100, 
                                          cv = 5, 
                                          verbose=2, 
                                          random_state=42, 
                                          n_jobs = -1)
    
    # Fit the random search model
    rf_randomized_cv.fit(x_train, y_train)
    
    print(rf_randomized_cv.best_params_)
    return rf_randomized_cv.best_estimator_

# %%
#EXAMPLE
#Random state
#CHOOSE IF REGRESSOR OR CLASSIFICATION
random_tuned_model = randomized_cv(x_train, y_train, RandomForestRegressor())
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   3.9s
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   3.9s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.0s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   4.8s
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   4.8s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   4.8s
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   4.9s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   4.9s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.8s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.7s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.7s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.7s
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.8s
# [CV] n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   2.4s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.1s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   4.1s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   2.5s
# [CV] n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   2.5s
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   2.6s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=733, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=70, total=   2.8s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=100, total=   0.3s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.3s
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.7s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.7s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.7s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   5.6s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   5.5s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.6s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=100, total=   1.6s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   5.5s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   5.5s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1788, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=50, total=   5.4s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.3s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.5s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.6s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.5s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   4.6s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   5.2s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   5.2s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   5.3s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   5.2s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   3.8s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.3s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   3.7s
# [CV] n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   3.7s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=60, total=   5.1s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   3.8s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=None, total=   3.8s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.2s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.1s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.5s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.1s
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.2s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.1s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.5s
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.5s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=40, total=   2.7s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   3.6s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   3.0s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   3.2s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   3.3s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   3.6s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   3.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   3.2s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, total=   3.4s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.0s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   5.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   2.9s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   6.0s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   5.7s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   2.9s
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   5.8s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=1577, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=40, total=   6.0s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   2.9s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   1.2s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   1.2s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   1.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   1.3s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=100, total=   1.3s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   7.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   7.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   7.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   7.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.8s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=10, total=   7.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   0.3s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.9s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   1.3s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   1.3s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   1.3s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   1.3s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   1.3s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.8s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.7s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.7s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.7s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=70, total=   2.7s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   5.1s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   5.0s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   5.1s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   3.9s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   4.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   3.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   3.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   4.9s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   4.8s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=90, total=   4.8s
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV] n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=sqrt, max_depth=20, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=60, total=   0.3s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.3s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   1.2s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   1.3s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=60, total=   4.6s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.0s
# [CV]  n_estimators=1366, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=90, total=   4.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   1.2s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=80, total=   0.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   1.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=20, total=   1.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   4.5s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   4.5s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   4.5s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   4.4s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=60, total=   4.4s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.0min
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.1s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.1s
# [CV] n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   2.1s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   2.1s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   2.1s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   6.1s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.7s
# [CV] n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.7s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.7s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.8s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=10, total=   0.8s
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.9s
# [CV]  n_estimators=522, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=None, total=   1.9s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV] n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   5.5s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   5.5s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.0s
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.0s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   3.5s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.0s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=944, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   4.1s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   3.8s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   3.8s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   3.8s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   3.8s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.2s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.2s
# [CV] n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.2s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.2s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=100, total=   4.1s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.9s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   2.0s
# [CV] n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   6.0s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   2.1s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   2.0s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=522, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=None, total=   1.9s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   5.9s
# [CV] n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   6.0s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.8s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.8s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   5.9s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=100, total=   6.0s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.8s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.9s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=522, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.9s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   1.1s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   1.0s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   1.1s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   1.1s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=80, total=   1.1s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   4.5s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   4.4s
# [CV] n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   4.4s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   4.5s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   4.6s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   2.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   2.9s
# [CV] n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   2.9s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   7.4s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   7.4s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   7.5s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   3.2s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110, total=   3.2s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   7.6s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80, total=   2.0s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=80, total=   2.1s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=90, total=   7.5s
# [CV] n_estimators=733, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=110
# ...
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   2.6s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   2.6s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=70, total=   2.6s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.3s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.2s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   6.8s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   6.8s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.3s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   6.7s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.0s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   6.8s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=50, total=   6.8s
# [CV] n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, total=   1.1s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.7s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.7s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.1s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.0s
# [CV] n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.1s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.0s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=110, total=   4.1s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   6.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   6.3s
# [CV] n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   6.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.5s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.5s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   6.4s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.5s
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=40, total=   0.5s
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV] n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1788, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=80, total=   6.7s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   6.7s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   4.5s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   5.4s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   5.3s
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   5.3s
# [CV] n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   5.3s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=1366, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   5.4s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=2000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   7.2s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   1.4s
# [CV] n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   1.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   1.5s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   1.6s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   4.3s
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.4s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.4s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=100, total=   0.4s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=311, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=110, total=   1.8s
# [CV] n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   4.4s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   4.3s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1155, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   4.4s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   5.9s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   6.0s
# [CV] n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   5.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   5.8s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=1366, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   5.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=40, total=   0.3s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   7.5s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   7.5s
# [CV] n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   7.6s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   3.5s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   3.6s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   3.6s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.5s
# [CV]  n_estimators=944, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=None, total=   2.3s
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   6.3s
# [CV]  n_estimators=1577, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   6.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  3.6min finished
# {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 20}

# %%
random_tuned_model.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=4, min_samples_split=10,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)>

# %% [markdown]
# ### Step 2: Grid Search CV

# %%
def grid_cv(x_train, y_train, model):
    param_grid = {
        'max_depth': [15, 20, 30, 50],
        'max_features': [2, 3, 4],
        'min_samples_leaf': [1, 4, 5],
        'min_samples_split': [8, 10, 5],
        'n_estimators': [500, 1500]
    }
    # Create a based model
    rf = model
    # Instantiate the grid search model
    grid_search = GridSearchCV(estimator = rf, 
                               param_grid = param_grid, 
                               cv = 5, n_jobs = -1, 
                               verbose = 2)
    grid_search.fit(x_train, y_train)
    
    print(grid_search.best_params_)
    return grid_search.best_estimator_

# %%
#Example
#CHOOSE IF REGRESSOR OR CLASSIFICATION
tuned_model = grid_cv(x_train, y_train, RandomForestRegressor())
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.1s
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    6.7s
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   3.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   3.1s
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   0.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   3.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   2.9s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   3.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   3.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   3.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   3.1s
# [CV]  max_depth=15, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.3s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.3s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.3s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.0s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.5s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   3.8s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   45.4s
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   3.9s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.2s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.1s
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV] max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   4.2s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.6s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.5s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.2s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.4s
# [CV] max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=15, max_features=4, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# ...
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  2.0min
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.5s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   1.5s
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=5, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.9s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=8, n_estimators=1500, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV] max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.7s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1500, total=   3.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1500, total=   4.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=1500, total=   4.0s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   3.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   3.8s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=500, total=   1.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=1500, total=   4.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.4s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.3s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500, total=   1.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.2s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=5, n_estimators=1500, total=   4.1s
# [CV] max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500

# %%
tuned_model.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features=2, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=4,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1500, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)>

# %% [markdown]
# # <span style="color:STEELBLUE">**Run Models**</span>

# %% [markdown]
# ### Tuned Model - will either be regression or classification depending on what you chose in the tune functions

# %%
def run_tuned_model(x_train,y_train):
    tuned_model.fit(x_train, y_train)
    return tuned_model

# %%
hypertune_model = run_tuned_model(x_train, y_train)

# %% [markdown]
# ----------------

# %% [markdown]
# ### Standard Regression Model

# %%
def run_regression(x_train, y_train):
    reg_model = RandomForestRegressor(random_state=42, n_estimators=1500, min_samples_split=5, 
                                      max_depth = 30, max_features='auto', min_samples_leaf=1) 
    reg_model.fit(x_train, y_train)
    return reg_model

# %%
# EXAMPLE
# Careful of Random State
reg_model = run_regression(x_train, y_train)

# %% [markdown]
# ----------------

# %% [markdown]
# ### Standard Classification Model

# %%
def run_classification(x_train, y_train,):
    class_model = RandomForestClassifier(random_state=42)
    class_model.fit(x_train, y_train)
    return class_model

# %%
# EXAMPLE
# Careful of Random State
class_model = run_classification(x_train, y_train)

# %% [markdown]
# # <span style="color:STEELBLUE">**Evaluate Models**</span>

# %% [markdown]
# ### Make Predictions

# %%
def prediction(model, x_train, x_test):
    pred_train = model.predict(x_train)
    pred_test = model.predict(x_test)   
    return pred_train, pred_test

# %%
# EXAMPLE
#CHOOSE MODEL
pred_train, pred_test = prediction(hypertune_model, x_train, x_test)

# %% [markdown]
# ### Evaluate Regression

# %%
def evaluate_regression(pred_train, pred_test, y_train, y_test):
    r_train = r2_score(y_train, pred_train)
    print('The training r-squared score is {}'.format(r_train))
    r_test = r2_score(y_test, pred_test)
    print('The testing r-squared score is {}'.format(r_test))
    meanabserrors_train = np.mean(abs(pred_train - y_train))
    print('The training mean absolute error is {}'.format(meanabserrors_train))
    meanabserrors_test = np.mean(abs(pred_test - y_test))
    print('The testing mean absolute error is {}'.format(meanabserrors_test))
    rmse = math.sqrt(mean_squared_error(y_test, pred_test))
    print('The root mean square error is {}'.format(rmse))
    mse = mean_squared_error(y_test, pred_test)
    print('The mean square error is {}'.format(mse))
    errors = pred_test - y_test
    meanerror = np.mean(errors)
    print('The mean error is {}'.format(meanerror))
    return errors

# %%
# EXAMPLE
errors = evaluate_regression(pred_train, pred_test, y_train, y_test)
# Out:
# The training r-squared score is 0.4621902157366564
# The testing r-squared score is 0.5022014301799755
# The training mean absolute error is 0.017414108641477053
# The testing mean absolute error is 0.01711041693610598
# The root mean square error is 0.023510548665756734
# The mean square error is 0.0005527458985649157
# The mean error is 0.0008861415289027459

# %%
def analyze_errors(errors):
    error_range =  max(errors) - min(errors)
    print('The error range is {}'.format(error_range))
    error_max = max(errors)
    print('The error max is {}'.format(error_max))
    error_min = min(errors)
    print('The error min is {}'.format(error_min))

# %%
# EXAMPLE
analyze_errors(errors)
# Out:
# The error range is 0.15752209355280622
# The error max is 0.0532137162951132
# The error min is -0.10430837725769301

# %%
def plot_errors(errors):
    plt.hist(errors, 30, histtype='bar', ec='white', color='maroon')
    plt.xlabel('Error')
    plt.ylabel('Count')
    plt.title('Histogram of Model Error')
    plt.grid(True)
    plt.show()

# %%
# EXAMPLE
plot_errors(errors)

# %%
def plot_predictions(y_test, pred, Title):
    df_predictions = pd.DataFrame(y_test)
    df_predictions['Pred'] = pred
    X = df_predictions.iloc[:, 0].values.reshape(-1, 1)
    Y = df_predictions.iloc[:, 1].values.reshape(-1, 1)
    fig, ax = plt.subplots()
    ax.scatter(X, Y, color='maroon')
    line = mlines.Line2D([0, 1], [0, 1], color='orange')
    transform = ax.transAxes
    line.set_transform(transform)
    ax.add_line(line)
    ax.set_xlabel(ax.get_xlabel(), fontsize = 18)
    ax.set_ylabel(ax.get_ylabel(), fontsize = 18)
    ax.tick_params(axis='both', which='major', labelsize=15)
    plt.grid(True)
    plt.xlabel("Damage Index")
    plt.ylabel("Precited Damage Index")
    plt.xlim(0, 0.2)
    plt.ylim(0, 0.2)
    plt.title('Model Evaluation -' +  Title, fontsize = 20)
    #plt.savefig('test_eval.png', dpi=600, bbox_inches = "tight")
    plt.show()

# %%
# EXAMPLE
Title = 'Test Set'
plot_predictions(y_test, pred_test, Title)

# %%
Title = 'Train Set'
plot_predictions(y_train, pred_train, Title)

# %% [markdown]
# -----------

# %% [markdown]
# ### Evaluate Classification

# %%
def evaluate_classification(model, x_train, x_test, y_train, y_test):
    pred = model.predict(x_test)
    accuracy_train = model.score(x_train, y_train)
    print('The mean training accuracy is {}'.format(accuracy_train))
    accuracy_test = model.score(x_test, y_test)
    print('The mean test accuracy is {}'.format(accuracy_test))
    df_confusion = pd.DataFrame(confusion_matrix(y_test, pred))
    print(df_confusion)
    print(classification_report(y_test, pred))
    return df_confusion

# %%
# EXAMPLE
# CHOOSE MODEL IF WANT TUNED OR JUST CLASSIFICATION WITH DEFAULT
df_confusion = evaluate_classification(hypertune_model, x_train, x_test, y_train, y_test)
# Out:
# The mean training accuracy is 0.9929078014184397
# The mean test accuracy is 0.5310734463276836
#     0   1   2
# 0  30  16  13
# 1  12  31  17
# 2  11  14  33
#              precision    recall  f1-score   support
#
#           0       0.57      0.51      0.54        59
#           1       0.51      0.52      0.51        60
#           2       0.52      0.57      0.55        58
#
# avg / total       0.53      0.53      0.53       177

# %%
def plot_confusion(df_confusion):
    sns.set(font_scale=1.4)#for label size
    sns.heatmap(df_confusion, cmap='PuBu', annot=True, annot_kws={"size": 16})# font size
    plt.ylabel('Predicted')
    plt.xlabel('True Value')
#     plt.savefig('classification.png', dpi=600, bbox_inches = "tight")
    plt.show()

# %%
# EXAMPLE
plot_confusion(df_confusion)

# %% [markdown]
# # <span style="color:STEELBLUE">**Analyze Results**</span>

# %% [markdown]
# ## Gini Importance Calculation

# %% [markdown]
# Tree based models provides a different measure of feature importances based on the mean decrease in impurity (MDI, the splitting criterion - The function to measure the quality of a split. Supported criteria are “mse” for the mean squared error, which is equal to variance reduction as feature selection criterion, and “mae” for the mean absolute error). This gives importance to features that may not be predictive on unseen data. The permutation feature importance avoids this issue, since it can be applied to unseen data. Furthermore, impurity-based feature importance for trees are strongly biased and favor high cardinality features (typically numerical features). Permutation-based feature importances do not exhibit such a bias. Additionally, the permutation feature importance may use an arbitrary metric on the tree’s predictions. These two methods of obtaining feature importance are explored in: Permutation Importance vs Random Forest Feature Importance (MDI).

# %% [markdown]
# In scikit-learn, importance of a node 𝑗 in a decision tree is computed (source code) as: \
# ![alt text](nodeimportance.png "Title") \
# where 𝑤𝑗 is weighted number of samples in node 𝑗, 𝐶𝑗 is impurity in this node, and 𝑙𝑒𝑓𝑡(𝑗) and 𝑟𝑖𝑔ℎ𝑡(𝑗) are its respective children nodes.
#
# Then feature importance of feature 𝑖 is computed as:\
# ![alt text](featureimportance.png "Title") \
# In RandomForest or GradientBoosting, feature importances are then averaged over all the trees (source code).
#
# In short, (un-normalized) feature importance of a feature is a sum of importances of the corresponding nodes. So if you take a set of features, it would be totally consistent to represent the importance of this set as sum of importances of all the corresponding nodes. And the latter exactly equals sum of individual feature importances. And normailizing denominator is the same for all the features, so does not change relative importances.

# %%
def calc_gini_importances(x_train, model):
    importances = model.feature_importances_
    importances_df = pd.DataFrame(importances, x_train.columns,
                                  columns=['Importance']).sort_values('Importance',
                                  ascending=False)
    importances_df.reset_index(inplace=True)
    importances_df.rename(columns={'index':'Feature'}, inplace=True)
    return importances_df

# %%
# indicate if reg_model or class_model
# EXAMPLE
df_gini_importances = calc_gini_importances(x_train, hypertune_model)

# %% [markdown]
# ## Gini Plot

# %%
def gini_importance_plot(df_gini_importances):
    df_gini_importances.sort_values('Importance', ascending=False).plot.bar('Feature',
                                                                            'Importance', 
                                                                            color='maroon', 
                                                                            legend = False)
    plt.title("Feature Importances", fontsize = 25)
    plt.ylabel('Importance', fontsize = 16)
    plt.xlabel('')
    plt.xticks(fontsize = 16, rotation = 45, ha='right')
    plt.yticks(fontsize = 14)
#     plt.savefig('giniimportance.png', dpi=600, bbox_inches = "tight")

# %%
# EXAMPLE
gini_importance_plot(df_gini_importances)

# %% [markdown]
# ## Permutation Importance Calculation

# %% [markdown]
# Permutation feature importance is a model inspection technique that can be used for any fitted estimator when the data is rectangular. This is especially useful for non-linear or opaque estimators. The permutation feature importance is defined to be the decrease in a model score when a single feature value is randomly shuffled 1. This procedure breaks the relationship between the feature and the target, thus the drop in the model score is indicative of how much the model depends on the feature. This technique benefits from being model agnostic and can be calculated many times with different permutations of the feature.
#
# The permutation_importance function calculates the feature importance of estimators for a given dataset. The n_repeats parameter sets the number of times a feature is randomly shuffled and returns a sample of feature importances. Permutation importances can either be computed on the training set or an held-out testing or validation set. Using a held-out set makes it possible to highlight which features contribute the most to the generalization power of the inspected model. Features that are important on the training set but not on the held-out set might cause the model to overfit.

# %%
def calc_permutation_importance(criterion, model, df_x, y):
    features = df_x.columns.values
    X = df_x.as_matrix()
    Y = y.as_matrix()
    scores = defaultdict(list)
    rf = model
    for train_idx, test_idx in ShuffleSplit(len(X), 100, .3, random_state=42): #number of splits, absolute number of test samples, proportion of data in train split
        X_train, X_test = X[train_idx], X[test_idx] #Random permutation cross-validator, Yields indices to split data into training and test sets.
        Y_train, Y_test = Y[train_idx], Y[test_idx]
        r = rf.fit(X_train, Y_train)
        acc = criterion(Y_test, rf.predict(X_test))
        for i in range(X.shape[1]): #The shape attribute for numpy arrays returns the dimensions of the array. If Y has n rows and m columns, then Y.shape is (n,m). So Y.shape[0] is n.
            X_t = X_test.copy()
            np.random.seed(42)
            np.random.shuffle(X_t[:, i]) #rearranging randomly
            shuff_acc = criterion(Y_test, rf.predict(X_t)) 
            scores[features[i]].append((acc-shuff_acc)/acc) #change in importance, actual - shuffled/actual, this is percent error        
    mda_features = [f for f in scores.keys()]
    mda_importance = [(np.mean(score)) for score in scores.values()] #average over all the shuffled permutations
    mda_indices = np.argsort(mda_importance)
    return mda_features, mda_importance, mda_indices

# %%
#EXAMPLE
#criterion can be r2_score or mean_squared_error
#should be mean_squared_error i think

criterion = mean_squared_error
mda_features, mda_importance, mda_indices = calc_permutation_importance(criterion, hypertune_model, df_x, y)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Permutation Plot

# %%
def permutation_importance_plot(mda_features, mda_importance):
    df_perm_FI = pd.DataFrame({'Feature':mda_features, 'Importance':[abs(number) for number in mda_importance]})
    df_perm_FI.sort_values('Importance', ascending=False).plot.bar('Feature',
                                                                   'Importance', 
                                                                    color='maroon', 
                                                                    legend = False)
    plt.title("Feature Importances", fontsize = 30)
    plt.ylabel('Importance')
    plt.xlabel('')
    plt.xticks(fontsize = 12, rotation = 45, ha='right')
    plt.savefig('permutimportance.png', dpi=600, bbox_inches = "tight")

# %%
# EXAMPLE
permutation_importance_plot(mda_features, mda_importance)

# %% [markdown]
# ## Export

# %%
train_set = x_train.copy()
test_set = x_test.copy()

# %%
train_set['y_train'] = y_train
train_set['train_pred'] = pred_train

test_set['y_test'] = y_test
test_set['test_pred'] = pred_test

# %%
train_set.to_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/train_set_20191031.xlsx")
test_set.to_excel("/Users/lszczyrba/Documents/Research/Projects/PR_Housing/Data/test_set_20191031.xlsx")

# %% [markdown]
# ### Tree Visualization

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = reg_model.estimators_[5]
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

feature_list = list(df_x.columns)


# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot', feature_names = feature_list, rounded = True, precision = 1)
#Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree.png')
